# %% [markdown]
# #### Analysis

# %% [markdown]
# We can get a general idea about the sales trends by taking a look at the various stats in comparison to the sales trends.
# This could give us an idea on further analysis to "zoom in" on a certain period of time.
# Due to the unmanagable nature of the number of stores utilized in the dataset, we moved on to only mapping the top 5 and bottom 5 stores.

# %% [markdown]
# ![Sales.png](attachment:6c4bb72b-c059-44ad-97ce-a00e27fd7a16.png)

# %% [markdown]
# While not incredible, we can see there were two major spikes in sales in the top stores, and they roughly translated to a few of the bottom stores.
# Let's add in Temperature.
# ![Temperature.png](attachment:351994aa-9fc2-4666-b2fd-fe835b5bc450.png)

# %% [markdown]
# Given that there are four years of temperature data, and the spikes in sales happened late 2010 and late 2011, these low temps occurred elsewhere, so the correlation probably isn't relevant.
# What would Fuel Price tell us?
# ![Fuel_Price.png](attachment:6bc2d35a-8c81-4a75-b01d-75a23ef8f9e2.png)

# %% [markdown]
# As we can see, there *was* a lowpoint of fuel prices in late 2010 that might've contributed, however, in late 2011 this wasn't the case, so this also probably is only incedentally connected.
# The Consumer Price Index (CPI) measures the average cost of a representative basket of goods.  This is often used to indicate inflation and the cost of living.
# ![CPI.png](attachment:0ba31045-e391-43b8-8d0a-95244a86e601.png)

# %% [markdown]
# Whelp, besides a general increase over time, we're not seeing any general correlation that lines up with our sales increases.
# Let's lastly try unemployment.
# ![Unemployment.png](attachment:d1dfc084-0675-4d84-972c-8501a338f9be.png)

# %% [markdown]
# Finally, this also isn't giving us any real indicators that explain our sales spikes.
# At this point, the best path forward is to communicate with the stakeholder explaining this.
# Further points of research could be things like marketing promotions, and introductions of new lines of product.  These most likely explain the sales spikes being that they also exist to a lesser degree in lower performing stores and external economic factors and seasonality don't seem to play a role.
